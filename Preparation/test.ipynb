# %%
import subprocess
import pkg_resources

def check_and_update_yfinance():
    try:
        # Check the installed version of yfinance
        installed_version = pkg_resources.get_distribution("yfinance").version
        print(f"Currently installed yfinance version: {installed_version}")
    except pkg_resources.DistributionNotFound:
        print("yfinance is not installed.")
        installed_version = None

    # Update or install the latest version
    print("Checking for the latest version of yfinance...")
    try:
        subprocess.check_call(["pip", "install", "--upgrade", "yfinance"])
        print("yfinance has been updated to the latest version.")
    except subprocess.CalledProcessError as e:
        print("An error occurred while updating yfinance:", e)

if __name__ == "__main__":
    check_and_update_yfinance()
# Out:
# Currently installed yfinance version: 0.2.43
# Checking for the latest version of yfinance...
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (0.2.43)
# Collecting yfinance
#   Downloading yfinance-0.2.50-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.50-py2.py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.43
#     Uninstalling yfinance-0.2.43:
#       Successfully uninstalled yfinance-0.2.43
# Successfully installed yfinance-0.2.50
# yfinance has been updated to the latest version.

# %%
import yfinance as yf

ticker = yf.Ticker('PM')
info = ticker.info
info
# Out:
# {'address1': '677 Washington Boulevard',
#  'address2': 'Suite 1100',
#  'city': 'Stamford',
#  'state': 'CT',
#  'zip': '06901',
#  'country': 'United States',
#  'phone': '203 905 2410',
#  'website': 'https://www.pmi.com',
#  'industry': 'Tobacco',
#  'industryKey': 'tobacco',
#  'industryDisp': 'Tobacco',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
#  'longBusinessSummary': "Philip Morris International Inc. operates as a tobacco company working to delivers a smoke-free future and evolving portfolio for the long-term to include products outside of the tobacco and nicotine sector. The company's product portfolio primarily consists of cigarettes and smoke-free products, including heat-not-burn, vapor, and oral nicotine products primarily under the IQOS and ZYN brands; and consumer accessories, such as lighters and matches. It also offers wellness and healthcare products. Philip Morris International Inc. was incorporated in 1987 and is headquartered in Stamford, Connecticut.",
#  'fullTimeEmployees': 82700,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Jacek  Olczak',
#    'age': 58,
#    'title': 'CEO & Director',
#    'yearBorn': 1965,
#    'fiscalYear': 2023,
#    'totalPay': 6198859,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Emmanuel  Babeau',
#    'age': 56,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 3531792,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frederic  de Wilde',
#    'age': 56,
#    'title': 'President of South & Southeast Asia, Commonwealth of Ind. States and Middle East & Africa Region',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 3327016,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Stacey  Kennedy',
#    'age': 50,
#    'title': 'President of Americas Region & CEO of US Business',
#    'yearBorn': 1973,
#    'fiscalYear': 2023,
#    'totalPay': 4426321,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Stefano  Volpetti',
#    'age': 51,
#    'title': 'President of Smoke-Free Inhalable Products & Chief Consumer Officer',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 2570559,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Scott  Coutts',
#    'title': 'Senior Vice President of Operations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank  De Rooij',
#    'age': 57,
#    'title': 'Vice President of Treasury & Corporate Finance',
#    'yearBorn': 1966,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Michael  Voegele',
#    'age': 50,
#    'title': 'Chief Digital & Information Officer',
#    'yearBorn': 1973,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James R. Bushnell',
#    'title': 'Vice President of Investor Relations & Financial Communications',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Yann  Guerin',
#    'age': 46,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1977,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 10,
#  'boardRisk': 4,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 5,
#  'overallRisk': 5,
#  'governanceEpochDate': 1730419200,
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 129.54,
#  'open': 129.62,
#  'dayLow': 128.84,
#  'dayHigh': 131.24,
#  'regularMarketPreviousClose': 129.54,
#  'regularMarketOpen': 129.62,
#  'regularMarketDayLow': 128.84,
#  'regularMarketDayHigh': 131.24,
#  'dividendRate': 5.4,
#  'dividendYield': 0.0417,
#  'exDividendDate': 1727308800,
#  'payoutRatio': 0.8333,
#  'fiveYearAvgDividendYield': 5.36,
#  'beta': 0.56,
#  'trailingPE': 20.74762,
#  'forwardPE': 18.310982,
#  'volume': 1561894,
#  'regularMarketVolume': 1561894,
#  'averageVolume': 5549314,
#  'averageVolume10days': 6730680,
#  'averageDailyVolume10Day': 6730680,
#  'bid': 130.61,
#  'ask': 130.66,
#  'bidSize': 800,
#  'askSize': 800,
#  'marketCap': 203231838208,
#  'fiftyTwoWeekLow': 87.82,
#  'fiftyTwoWeekHigh': 134.15,
#  'priceToSalesTrailing12Months': 5.4604325,
#  'fiftyDayAverage': 124.443,
#  'twoHundredDayAverage': 107.44015,
#  'trailingAnnualDividendRate': 5.25,
#  'trailingAnnualDividendYield': 0.040528025,
#  'currency': 'USD',
#  'enterpriseValue': 248407113728,
#  'profitMargins': 0.26417,
#  'floatShares': 1551008520,
#  'sharesOutstanding': 1554829952,
#  'sharesShort': 10018211,
#  'sharesShortPriorMonth': 8326970,
#  'sharesShortPreviousMonthDate': 1727654400,
#  'dateShortInterest': 1730332800,
#  'sharesPercentSharesOut': 0.0064,
#  'heldPercentInsiders': 0.00118,
#  'heldPercentInstitutions': 0.80426,
#  'shortRatio': 2.02,
#  'shortPercentOfFloat': 0.0064999997,
#  'impliedSharesOutstanding': 1554829952,
#  'bookValue': -6.235,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1727654400,
#  'earningsQuarterlyGrowth': 0.5,
#  'netIncomeToCommon': 9804999680,
#  'trailingEps': 6.3,
#  'forwardEps': 7.2,
#  'enterpriseToRevenue': 6.674,
#  'enterpriseToEbitda': 16.235,
#  '52WeekChange': 0.38072908,
#  'SandP52WeekChange': 0.29854584,
#  'lastDividendValue': 1.35,
#  'lastDividendDate': 1727308800,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'PM',
#  'underlyingSymbol': 'PM',
#  'shortName': 'Philip Morris International Inc',
#  'longName': 'Philip Morris International Inc.',
#  'firstTradeDateEpochUtc': 1205760600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '21b7eb30-013b-3477-af5b-06bc59209391',
#  'messageBoardId': 'finmb_6569181',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 130.71,
#  'targetHighPrice': 155.0,
#  'targetLowPrice': 102.0,
#  'targetMeanPrice': 136.0023,
#  'targetMedianPrice': 143.0,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 4257999872,
#  'totalCashPerShare': 2.739,
#  'ebitda': 15301000192,
#  'totalDebt': 49271001088,
#  'quickRatio': 0.404,
#  'currentRatio': 0.89,
#  'totalRevenue': 37219000320,
#  'revenuePerShare': 23.958,
#  'returnOnAssets': 0.13116,
#  'freeCashflow': 9205749760,
#  'operatingCashflow': 11516999680,
#  'earningsGrowth': 0.493,
#  'revenueGrowth': 0.084,
#  'grossMargins': 0.64075,
#  'ebitdaMargins': 0.41111,
#  'operatingMargins': 0.43425998,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 1.6071}
